# %%
from flair.data import TaggedCorpus
from flair.data_fetcher import NLPTaskDataFetcher, NLPTask
from flair.embeddings import TokenEmbeddings, FlairEmbeddings, WordEmbeddings, StackedEmbeddings, CharacterEmbeddings, CharLMEmbeddings
from flair.models import LanguageModel
from gensim.models.keyedvectors import KeyedVectors
from typing import List
import os
# Out:
# Better speed can be achieved with apex installed from https://www.github.com/nvidia/apex.

# %%
def read_data():
    # dirname = './conll_format'
    # define columns
    columns = {0: 'text', 1: 'pos', 2: 'np'}
    # this is the folder in which train, test and dev files reside
    data_folder = '../data/conll_format'
    # retrieve corpus using column format, data folder and the names of the train, dev and test files
    corpus: TaggedCorpus = NLPTaskDataFetcher.load_column_corpus(data_folder, columns,
                                                              train_file='arr.train',
                                                              test_file='arr.test',
                                                              dev_file='arr.dev')
    return corpus

# %%
corpus: TaggedCorpus = read_data()
print(corpus)

# %%
tag_type = 'ner'

# 3. make the tag dictionary from the corpus
tag_dictionary = corpus.make_tag_dictionary(tag_type=tag_type)
print(tag_dictionary.idx2item)
# Out:
# [b'<unk>', b'O', b'', b'<START>', b'<STOP>']

# %% [markdown]
# filename = '../data/embeddings/wikipedia-pubmed-and-PMC-w2v.bin'
# word_vectors = KeyedVectors.load_word2vec_format(filename, binary=True)
# word_vectors.save('../data/embeddings/wiki.bg.vec.gensim')

# %%
filename = '../data/embeddings/wiki.bg.vec.gensim'
pretrained_word2vec = WordEmbeddings(filename)

# %%
embedding_types: List[TokenEmbeddings] = [

    # WordEmbeddings('glove'),

    pretrained_word2vec,

    # comment in this line to use character embeddings
    # CharacterEmbeddings(),

    # comment in these lines to use contextual string embeddings
    FlairEmbeddings('news-forward'),
    FlairEmbeddings('news-backward'),
]

# %%
embeddings: StackedEmbeddings = StackedEmbeddings(embeddings=embedding_types)

# %%
# 5. initialize sequence tagger
from flair.models import SequenceTagger

tagger: SequenceTagger = SequenceTagger(hidden_size=50,
                                        embeddings=embeddings,
                                        tag_dictionary=tag_dictionary,
                                        tag_type=tag_type,
                                        use_crf=True)

# %%
# 6. initialize trainer
from flair.trainers import ModelTrainer

trainer: ModelTrainer = ModelTrainer(tagger, corpus)

# %%
# 7. start training
if os.path.isdir('../data/model') == False:
    os.mkdir('../data/model/my_flair_model')

# %%
trainer.train('../data/model/ner_model',
              learning_rate=0.015,
              mini_batch_size=10,
              max_epochs=50)
# Out:
# 2019-04-04 17:07:53,181 ----------------------------------------------------------------------------------------------------
# 2019-04-04 17:07:53,181 Evaluation method: MICRO_F1_SCORE
# 2019-04-04 17:07:53,204 ----------------------------------------------------------------------------------------------------
# 2019-04-04 17:07:53,257 epoch 1 - iter 0/13 - loss 3.66242485
# 2019-04-04 17:07:55,425 epoch 1 - iter 1/13 - loss 2.88163862
# 2019-04-04 17:07:57,449 epoch 1 - iter 2/13 - loss 4.09905949
# 2019-04-04 17:07:59,519 epoch 1 - iter 3/13 - loss 3.84855251
# 2019-04-04 17:08:01,459 epoch 1 - iter 4/13 - loss 3.39944244
# 2019-04-04 17:08:03,392 epoch 1 - iter 5/13 - loss 2.97377151
# 2019-04-04 17:08:05,330 epoch 1 - iter 6/13 - loss 2.76312207
# 2019-04-04 17:08:07,259 epoch 1 - iter 7/13 - loss 2.55219790
# 2019-04-04 17:08:09,124 epoch 1 - iter 8/13 - loss 2.36225913
# 2019-04-04 17:08:11,042 epoch 1 - iter 9/13 - loss 2.19429740
# 2019-04-04 17:08:12,981 epoch 1 - iter 10/13 - loss 2.05927547
# 2019-04-04 17:08:14,938 epoch 1 - iter 11/13 - loss 1.92118802
# 2019-04-04 17:08:16,835 epoch 1 - iter 12/13 - loss 1.86827375
# 2019-04-04 17:08:18,631 ----------------------------------------------------------------------------------------------------
# 2019-04-04 17:08:18,633 EPOCH 1 done: loss 1.8683 - lr 0.0150 - bad epochs 0
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-14-076e703aef5c> in <module>
#       2               learning_rate=0.015,
#       3               mini_batch_size=10,
# ----> 4               max_epochs=50)
#
# /opt/conda/envs/fastai/lib/python3.6/site-packages/flair/trainers/trainer.py in train(self, base_path, evaluation_metric, learning_rate, mini_batch_size, eval_mini_batch_size, max_epochs, anneal_factor, patience, anneal_against_train_loss, train_with_dev, monitor_train, embeddings_in_memory, checkpoint, save_final_model, anneal_with_restarts, test_mode, param_selection_mode, **kwargs)
#     185                 if not train_with_dev:
#     186                     dev_metric, dev_loss = self._calculate_evaluation_results_for(
# --> 187                         'DEV', self.corpus.dev, evaluation_metric, embeddings_in_memory, eval_mini_batch_size)
#     188
#     189                 if not param_selection_mode and self.corpus.test:
#
# /opt/conda/envs/fastai/lib/python3.6/site-packages/flair/trainers/trainer.py in _calculate_evaluation_results_for(self, dataset_name, dataset, evaluation_metric, embeddings_in_memory, eval_mini_batch_size, out_path)
#     320
#     321         metric, loss = ModelTrainer.evaluate(self.model, dataset, eval_mini_batch_size=eval_mini_batch_size,
# --> 322                                              embeddings_in_memory=embeddings_in_memory, out_path=out_path)
#     323
#     324         if evaluation_metric == EvaluationMetric.MACRO_ACCURACY or evaluation_metric == EvaluationMetric.MACRO_F1_SCORE:
#
# /opt/conda/envs/fastai/lib/python3.6/site-packages/flair/trainers/trainer.py in evaluate(model, data_set, eval_mini_batch_size, embeddings_in_memory, out_path)
#     344         elif isinstance(model, SequenceTagger):
#     345             return ModelTrainer._evaluate_sequence_tagger(model, data_set, eval_mini_batch_size, embeddings_in_memory,
# --> 346                                                           out_path)
#     347
#     348     @staticmethod
#
# /opt/conda/envs/fastai/lib/python3.6/site-packages/flair/trainers/trainer.py in _evaluate_sequence_tagger(model, sentences, eval_mini_batch_size, embeddings_in_memory, out_path)
#     365                 batch_no += 1
#     366
# --> 367                 tags, loss = model.forward_labels_and_loss(batch)
#     368
#     369                 eval_loss += loss
#
# /opt/conda/envs/fastai/lib/python3.6/site-packages/flair/models/sequence_tagger_model.py in forward_labels_and_loss(self, sentences, sort)
#     266                                 sort=True) -> (List[List[Label]], torch.tensor):
#     267         with torch.no_grad():
# --> 268             feature, lengths, tags = self.forward(sentences, sort=sort)
#     269             loss = self._calculate_loss(feature, lengths, tags)
#     270             tags = self._obtain_labels(feature, lengths)
#
# /opt/conda/envs/fastai/lib/python3.6/site-packages/flair/models/sequence_tagger_model.py in forward(self, sentences, sort)
#     313         self.zero_grad()
#     314
# --> 315         self.embeddings.embed(sentences)
#     316
#     317         # if sorting is enabled, sort sentences by number of tokens
#
# /opt/conda/envs/fastai/lib/python3.6/site-packages/flair/embeddings.py in embed(self, sentences, static_embeddings)
#     128
#     129         for embedding in self.embeddings:
# --> 130             embedding.embed(sentences)
#     131
#     132     @property
#
# /opt/conda/envs/fastai/lib/python3.6/site-packages/flair/embeddings.py in embed(self, sentences)
#      61
#      62         if not everything_embedded or not self.static_embeddings:
# ---> 63             self._add_embeddings_internal(sentences)
#      64
#      65         return sentences
#
# /opt/conda/envs/fastai/lib/python3.6/site-packages/flair/embeddings.py in _add_embeddings_internal(self, sentences)
#     921
#     922             # get hidden states from language model
# --> 923             all_hidden_states_in_lm = self.lm.get_representation(sentences_padded, self.chars_per_chunk)
#     924
#     925             # take first or last hidden states from language model as word representation
#
# /opt/conda/envs/fastai/lib/python3.6/site-packages/flair/models/language_model.py in get_representation(self, strings, chars_per_chunk)
#     116             batch = batch.to(flair.device)
#     117
# --> 118             prediction, rnn_output, hidden = self.forward(batch, hidden)
#     119             rnn_output = rnn_output.detach()
#     120
#
# /opt/conda/envs/fastai/lib/python3.6/site-packages/flair/models/language_model.py in forward(self, input, hidden, ordered_sequence_lengths)
#      74         self.rnn.flatten_parameters()
#      75
# ---> 76         output, hidden = self.rnn(emb, hidden)
#      77
#      78         if self.proj is not None:
#
# /opt/conda/envs/fastai/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     487             result = self._slow_forward(*input, **kwargs)
#     488         else:
# --> 489             result = self.forward(*input, **kwargs)
#     490         for hook in self._forward_hooks.values():
#     491             hook_result = hook(self, input, result)
#
# /opt/conda/envs/fastai/lib/python3.6/site-packages/torch/nn/modules/rnn.py in forward(self, input, hx)
#     177         if batch_sizes is None:
#     178             result = _impl(input, hx, self._flat_weights, self.bias, self.num_layers,
# --> 179                            self.dropout, self.training, self.bidirectional, self.batch_first)
#     180         else:
#     181             result = _impl(input, batch_sizes, hx, self._flat_weights, self.bias,
#
# RuntimeError: CUDA out of memory. Tried to allocate 73.62 MiB (GPU 0; 23.88 GiB total capacity; 12.76 GiB already allocated; 16.56 MiB free; 10.41 GiB cached)
